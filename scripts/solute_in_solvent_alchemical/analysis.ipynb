# %%
import numpy as np
import pandas as pd
import signac
import json
from typing import Tuple
import matplotlib.pyplot as plt

from martignac.workflows.solute_in_solvent_alchemical import project

pd.set_option("display.precision", 2)

# %%
project
# Out:
# SoluteInSolventAlchemicalFlow('/Users/bereau/work/projects/martignac/workspaces/alchemical_transformation')

# %%
df = project.to_dataframe()
df.head()
# Out:
#                                                     sp.type sp.solvent_name  \
# d0a06838950a334d442e1cd0130fb155  alchemical_transformation             CLF
# 480123ac5874ff44b7b0dbe4c145670b  alchemical_transformation              HD
# 899b05f6088670fc1111d66c3a879891  alchemical_transformation             OCO
# f6fb8f62c684984898181f51c4f430d6  alchemical_transformation               W
# b6baf4f686816c57435971b0290c8191  alchemical_transformation            CHEX
#
#                                  sp.solute_name  sp.lambda_state  \
# d0a06838950a334d442e1cd0130fb155             P6                8
# 480123ac5874ff44b7b0dbe4c145670b             Q1               10
# 899b05f6088670fc1111d66c3a879891             Q1                5
# f6fb8f62c684984898181f51c4f430d6              D                3
# b6baf4f686816c57435971b0290c8191              D                5
#
#                                                   doc.SoluteInSolventAlchemicalFlow  \
# d0a06838950a334d442e1cd0130fb155  {'files_symlinked': True, 'fetched_nomad': Tru...
# 480123ac5874ff44b7b0dbe4c145670b  {'files_symlinked': True, 'fetched_nomad': Tru...
# 899b05f6088670fc1111d66c3a879891  {'files_symlinked': True, 'fetched_nomad': Tru...
# f6fb8f62c684984898181f51c4f430d6  {'files_symlinked': True, 'fetched_nomad': Tru...
# b6baf4f686816c57435971b0290c8191  {'files_symlinked': True, 'fetched_nomad': Tru...
#
#                                                                   doc.SoluteGenFlow  \
# d0a06838950a334d442e1cd0130fb155  {'files_symlinked': True, 'fetched_nomad': Tru...
# 480123ac5874ff44b7b0dbe4c145670b  {'files_symlinked': True, 'fetched_nomad': Tru...
# 899b05f6088670fc1111d66c3a879891  {'files_symlinked': True, 'fetched_nomad': Tru...
# f6fb8f62c684984898181f51c4f430d6  {'files_symlinked': True, 'fetched_nomad': Tru...
# b6baf4f686816c57435971b0290c8191  {'files_symlinked': True, 'fetched_nomad': Tru...
#
#                                                                  doc.SolventGenFlow  \
# d0a06838950a334d442e1cd0130fb155  {'files_symlinked': True, 'fetched_nomad': Tru...
# 480123ac5874ff44b7b0dbe4c145670b  {'files_symlinked': True, 'fetched_nomad': Tru...
# 899b05f6088670fc1111d66c3a879891  {'files_symlinked': True, 'fetched_nomad': Tru...
# f6fb8f62c684984898181f51c4f430d6  {'files_symlinked': True, 'fetched_nomad': Tru...
# b6baf4f686816c57435971b0290c8191  {'files_symlinked': True, 'fetched_nomad': Tru...
#
#                                                          doc.SoluteInSolventGenFlow
# d0a06838950a334d442e1cd0130fb155  {'files_symlinked': True, 'fetched_nomad': Tru...
# 480123ac5874ff44b7b0dbe4c145670b  {'files_symlinked': True, 'fetched_nomad': Tru...
# 899b05f6088670fc1111d66c3a879891  {'files_symlinked': True, 'fetched_nomad': Tru...
# f6fb8f62c684984898181f51c4f430d6  {'files_symlinked': True, 'fetched_nomad': Tru...
# b6baf4f686816c57435971b0290c8191  {'files_symlinked': True, 'fetched_nomad': Tru...

# %%
df_f = pd.DataFrame(
    df.groupby(['sp.solvent_name', 'sp.solute_name']).first()['doc.SoluteInSolventAlchemicalFlow'].apply(lambda x: x['free_energy']['mean'] if 'free_energy' in x.keys() else None)
).reset_index()
df_f = df_f.pivot(index="sp.solute_name", columns="sp.solvent_name", values='doc.SoluteInSolventAlchemicalFlow')
df_f = df_f.apply(lambda x: x * 2.479) # kT to kJ/mol at 298K
df_f = df_f.iloc[:, :-1].sub(df_f["W"], axis=0).assign(W=df_f["W"])
df_f.rename(columns={'BENZ': "BENZ -> W", "CHEX": "CHEX -> W", "CLF": "CLF -> W", "ETH": "ETH -> W", "HD": "HD -> W", "OCO": "OCO -> W"}, inplace=True)
df_f = df_f[["HD -> W", "OCO -> W", "CLF -> W", "ETH -> W", "BENZ -> W", "CHEX -> W", "W"]].reset_index()
df_f.columns.name = None
df_f = df_f.set_index("sp.solute_name")
df_f.index.name = "bead"
df_f.head()
# Out:
#      HD -> W OCO -> W CLF -> W ETH -> W BENZ -> W CHEX -> W    W
# bead
# D        NaN      NaN      NaN      NaN       NaN       NaN  NaN
# N3a      NaN      NaN      NaN      NaN       NaN       NaN  NaN
# P6       NaN      NaN      NaN      NaN       NaN       NaN  NaN
# Q1       NaN      NaN      NaN      NaN       NaN       NaN  NaN

# %%
df_martini = pd.read_csv("martini_reg_ref.csv")
df_martini = df_martini.rename(
    columns={
        "Bead": "bead", 
        'Oil-water transfer ΔG (HD→W)': "HD -> W",
        'Oil-water transfer ΔG (OCO→W)': "OCO -> W",
        'Oil-water transfer ΔG (CLF→W)': "CLF -> W",
        'Oil-water transfer ΔG (ETH→W)': "ETH -> W",
        'Oil-water transfer ΔG (BENZ→W)': "BENZ -> W", 
        'Oil-water transfer ΔG (CHEX→W)': "CHEX -> W",
        'Hydration ΔG': "W"
    }
).drop('Vaporization ΔG', axis=1).set_index("bead")
df_martini.head()
# Out:
#       HD -> W  OCO -> W  CLF -> W  ETH -> W  BENZ -> W  CHEX -> W    W
# bead
# C1       17.2      18.9      17.2      14.5       14.9       20.0 -8.6
# C2       15.4      14.8      14.3      12.9       12.1       16.9 -5.7
# C3       13.5      13.8      13.3      13.3       15.1       16.3 -4.8
# C4       10.6      13.4      13.6      13.7       18.0       16.3 -5.1
# C5        8.8      11.2      12.1      11.9       16.7       13.2 -3.6

# %%
bead_mapping = {
    'N3a': 'N3d/a',
    'N3d': 'N3d/a',
    'Q2+': 'Q2',
}

def map_beads(bead):
    return bead_mapping.get(bead, bead)

df_f.index = [map_beads(bead) for bead in df_f.index]
df_f.index.name = "bead"

identical_beads = pd.merge(df_f, df_martini, on="bead").index
identical_beads
# Out:
# Index(['Q1', 'Q2'], dtype='object', name='bead')

# %%
df_comp = df_f.loc[identical_beads].copy().compare(df_martini.loc[identical_beads].copy())
df_comp
# Out:
#      HD -> W       OCO -> W       CLF -> W       ETH -> W       BENZ -> W  \
#         self other     self other     self other     self other      self
# bead
# Q1    -21.75 -24.2    -9.17 -10.9    -8.85  -9.5    -1.02  -2.6     -3.10
# Q2    -30.33 -32.7   -16.05 -15.1   -13.67 -13.9    -4.85  -5.1    -10.19
#
#            CHEX -> W            W
#      other      self other   self other
# bead
# Q1    -4.7    -11.07 -12.5  21.59  23.2
# Q2   -10.4    -17.61 -17.1  25.50  25.5

# %%
# Define the threshold for highlighting
thresholds = [1.0, 2.0, 3.0]
colors = ["yellow", "orange", "red"]

# Extract 'self' and 'other' values from the comparison DataFrame
df_self = df_comp.loc[:, (slice(None), 'self')]
df_other = df_comp.loc[:, (slice(None), 'other')]

# Function to apply highlighting to the 'self' values
def apply_highlighting(df_self, df_other):
    # Prepare a DataFrame to hold styles
    styles = pd.DataFrame('', index=df_self.index, columns=df_self.columns)

    def format_value(val):
        try:
            return '{:.2f}'.format(val)
        except (TypeError, ValueError):
            return val
    
    # Apply highlighting only to 'self' values
    for row in range(df_self.shape[0]):
        for col in range(df_self.shape[1]):
            val_self = df_self.iloc[row, col]
            val_other = df_other.iloc[row, col]

            for threshold, color in zip(thresholds, colors):
                if abs(val_self - val_other) > threshold:
                    styles.iloc[row, col] = f'background-color: {color}'

    
    return df_comp.style.format(format_value).apply(lambda x: styles, axis=None)

# Apply highlighting and display the styled DataFrame
styled_comp = apply_highlighting(df_self, df_other)
styled_comp
# Out:
# <style type="text/css">
# #T_e5e71_row0_col0, #T_e5e71_row1_col0 {
#   background-color: orange;
# }
# #T_e5e71_row0_col2, #T_e5e71_row0_col6, #T_e5e71_row0_col8, #T_e5e71_row0_col10, #T_e5e71_row0_col12 {
#   background-color: yellow;
# }
# </style>
# <table id="T_e5e71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5e71_level0_col0" class="col_heading level0 col0" colspan="2">HD -> W</th>
#       <th id="T_e5e71_level0_col2" class="col_heading level0 col2" colspan="2">OCO -> W</th>
#       <th id="T_e5e71_level0_col4" class="col_heading level0 col4" colspan="2">CLF -> W</th>
#       <th id="T_e5e71_level0_col6" class="col_heading level0 col6" colspan="2">ETH -> W</th>
#       <th id="T_e5e71_level0_col8" class="col_heading level0 col8" colspan="2">BENZ -> W</th>
#       <th id="T_e5e71_level0_col10" class="col_heading level0 col10" colspan="2">CHEX -> W</th>
#       <th id="T_e5e71_level0_col12" class="col_heading level0 col12" colspan="2">W</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_e5e71_level1_col0" class="col_heading level1 col0" >self</th>
#       <th id="T_e5e71_level1_col1" class="col_heading level1 col1" >other</th>
#       <th id="T_e5e71_level1_col2" class="col_heading level1 col2" >self</th>
#       <th id="T_e5e71_level1_col3" class="col_heading level1 col3" >other</th>
#       <th id="T_e5e71_level1_col4" class="col_heading level1 col4" >self</th>
#       <th id="T_e5e71_level1_col5" class="col_heading level1 col5" >other</th>
#       <th id="T_e5e71_level1_col6" class="col_heading level1 col6" >self</th>
#       <th id="T_e5e71_level1_col7" class="col_heading level1 col7" >other</th>
#       <th id="T_e5e71_level1_col8" class="col_heading level1 col8" >self</th>
#       <th id="T_e5e71_level1_col9" class="col_heading level1 col9" >other</th>
#       <th id="T_e5e71_level1_col10" class="col_heading level1 col10" >self</th>
#       <th id="T_e5e71_level1_col11" class="col_heading level1 col11" >other</th>
#       <th id="T_e5e71_level1_col12" class="col_heading level1 col12" >self</th>
#       <th id="T_e5e71_level1_col13" class="col_heading level1 col13" >other</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bead</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5e71_level0_row0" class="row_heading level0 row0" >Q1</th>
#       <td id="T_e5e71_row0_col0" class="data row0 col0" >-21.75</td>
#       <td id="T_e5e71_row0_col1" class="data row0 col1" >-24.20</td>
#       <td id="T_e5e71_row0_col2" class="data row0 col2" >-9.17</td>
#       <td id="T_e5e71_row0_col3" class="data row0 col3" >-10.90</td>
#       <td id="T_e5e71_row0_col4" class="data row0 col4" >-8.85</td>
#       <td id="T_e5e71_row0_col5" class="data row0 col5" >-9.50</td>
#       <td id="T_e5e71_row0_col6" class="data row0 col6" >-1.02</td>
#       <td id="T_e5e71_row0_col7" class="data row0 col7" >-2.60</td>
#       <td id="T_e5e71_row0_col8" class="data row0 col8" >-3.10</td>
#       <td id="T_e5e71_row0_col9" class="data row0 col9" >-4.70</td>
#       <td id="T_e5e71_row0_col10" class="data row0 col10" >-11.07</td>
#       <td id="T_e5e71_row0_col11" class="data row0 col11" >-12.50</td>
#       <td id="T_e5e71_row0_col12" class="data row0 col12" >21.59</td>
#       <td id="T_e5e71_row0_col13" class="data row0 col13" >23.20</td>
#     </tr>
#     <tr>
#       <th id="T_e5e71_level0_row1" class="row_heading level0 row1" >Q2</th>
#       <td id="T_e5e71_row1_col0" class="data row1 col0" >-30.33</td>
#       <td id="T_e5e71_row1_col1" class="data row1 col1" >-32.70</td>
#       <td id="T_e5e71_row1_col2" class="data row1 col2" >-16.05</td>
#       <td id="T_e5e71_row1_col3" class="data row1 col3" >-15.10</td>
#       <td id="T_e5e71_row1_col4" class="data row1 col4" >-13.67</td>
#       <td id="T_e5e71_row1_col5" class="data row1 col5" >-13.90</td>
#       <td id="T_e5e71_row1_col6" class="data row1 col6" >-4.85</td>
#       <td id="T_e5e71_row1_col7" class="data row1 col7" >-5.10</td>
#       <td id="T_e5e71_row1_col8" class="data row1 col8" >-10.19</td>
#       <td id="T_e5e71_row1_col9" class="data row1 col9" >-10.40</td>
#       <td id="T_e5e71_row1_col10" class="data row1 col10" >-17.61</td>
#       <td id="T_e5e71_row1_col11" class="data row1 col11" >-17.10</td>
#       <td id="T_e5e71_row1_col12" class="data row1 col12" >25.50</td>
#       <td id="T_e5e71_row1_col13" class="data row1 col13" >25.50</td>
#     </tr>
#   </tbody>
# </table>
