# %%
import numpy as np
import pandas as pd
import signac
import json
from typing import Tuple
import matplotlib.pyplot as plt

from martignac.workflows.solute_in_solvent_alchemical import project

pd.set_option("display.precision", 2)
# Out:
# 24-08-21 18:05:40 - pymbar.timeseries - WARNING - Warning on use of the timeseries module: If the inherent timescales of the system are long compared to those being analyzed, this statistical inefficiency may be an underestimate.  The estimate presumes the use of many statistically independent samples.  Tests should be performed to assess whether this condition is satisfied.   Be cautious in the interpretation of the data.
# 24-08-21 18:05:40 - pymbar.mbar_solvers - WARNING -
# ********* JAX NOT FOUND *********
#  PyMBAR can run faster with JAX
#  But will work fine without it
# Either install with pip or conda:
#       pip install pybar[jax]
#                OR
#       conda install pymbar
# *********************************
# 24-08-21 18:05:40 - pymbar.mbar_solvers - INFO - JAX was either not detected or disabled, using standard NumPy and SciPy
# 24-08-21 18:05:41 - MDAnalysis.coordinates.AMBER - WARNING - netCDF4 is not available. Writing AMBER ncdf files will be slow.

# %%
project
# Out:
# SoluteInSolventAlchemicalFlow('/Users/bereau/work/projects/martignac/workspaces/solute_in_solvent_alchemical')

# %%
df = project.to_dataframe()
df.head()
# Out:
#                                                        sp.type  \
# 58de058b31c7140d71d2f707001d8a6d  solute_in_solvent_alchemical
# 5cce056c213ac2ddf2755098fb9c29b0  solute_in_solvent_alchemical
# 94fd4677e59f0e4ab1c4a8c01d00bfba  solute_in_solvent_alchemical
# 8926c803cd797330ee7c8e545b713874  solute_in_solvent_alchemical
# b4e3df7fc6dd72505759959857a391fd  solute_in_solvent_alchemical
#
#                                  sp.solvent_name sp.solute_name  \
# 58de058b31c7140d71d2f707001d8a6d            CHEX             P6
# 5cce056c213ac2ddf2755098fb9c29b0            CHEX             P6
# 94fd4677e59f0e4ab1c4a8c01d00bfba               W             P6
# 8926c803cd797330ee7c8e545b713874             CLF             P6
# b4e3df7fc6dd72505759959857a391fd             CLF             P6
#
#                                   sp.lambda_state  \
# 58de058b31c7140d71d2f707001d8a6d                8
# 5cce056c213ac2ddf2755098fb9c29b0                5
# 94fd4677e59f0e4ab1c4a8c01d00bfba                4
# 8926c803cd797330ee7c8e545b713874                0
# b4e3df7fc6dd72505759959857a391fd                4
#
#                                                   doc.SoluteInSolventAlchemicalFlow  \
# 58de058b31c7140d71d2f707001d8a6d  {'files_symlinked': True, 'fetched_nomad': Tru...
# 5cce056c213ac2ddf2755098fb9c29b0  {'files_symlinked': True, 'fetched_nomad': Tru...
# 94fd4677e59f0e4ab1c4a8c01d00bfba  {'files_symlinked': True, 'fetched_nomad': Tru...
# 8926c803cd797330ee7c8e545b713874  {'files_symlinked': True, 'fetched_nomad': Tru...
# b4e3df7fc6dd72505759959857a391fd  {'files_symlinked': True, 'fetched_nomad': Tru...
#
#                                                                   doc.SoluteGenFlow  \
# 58de058b31c7140d71d2f707001d8a6d  {'files_symlinked': True, 'fetched_nomad': Tru...
# 5cce056c213ac2ddf2755098fb9c29b0  {'files_symlinked': True, 'fetched_nomad': Tru...
# 94fd4677e59f0e4ab1c4a8c01d00bfba  {'files_symlinked': True, 'fetched_nomad': Tru...
# 8926c803cd797330ee7c8e545b713874  {'files_symlinked': True, 'fetched_nomad': Tru...
# b4e3df7fc6dd72505759959857a391fd  {'files_symlinked': True, 'fetched_nomad': Tru...
#
#                                                                  doc.SolventGenFlow  \
# 58de058b31c7140d71d2f707001d8a6d  {'files_symlinked': True, 'fetched_nomad': Tru...
# 5cce056c213ac2ddf2755098fb9c29b0  {'files_symlinked': True, 'fetched_nomad': Tru...
# 94fd4677e59f0e4ab1c4a8c01d00bfba  {'files_symlinked': True, 'fetched_nomad': Tru...
# 8926c803cd797330ee7c8e545b713874  {'files_symlinked': True, 'fetched_nomad': Tru...
# b4e3df7fc6dd72505759959857a391fd  {'files_symlinked': True, 'fetched_nomad': Tru...
#
#                                                          doc.SoluteInSolventGenFlow  \
# 58de058b31c7140d71d2f707001d8a6d  {'files_symlinked': True, 'fetched_nomad': Tru...
# 5cce056c213ac2ddf2755098fb9c29b0  {'files_symlinked': True, 'fetched_nomad': Tru...
# 94fd4677e59f0e4ab1c4a8c01d00bfba  {'files_symlinked': True, 'fetched_nomad': Tru...
# 8926c803cd797330ee7c8e545b713874  {'files_symlinked': True, 'fetched_nomad': Tru...
# b4e3df7fc6dd72505759959857a391fd  {'files_symlinked': True, 'fetched_nomad': Tru...
#
#                                     doc.nomad_dataset_id
# 58de058b31c7140d71d2f707001d8a6d                     NaN
# 5cce056c213ac2ddf2755098fb9c29b0                     NaN
# 94fd4677e59f0e4ab1c4a8c01d00bfba  HJdEI1q4SV-c5Di43BTT_Q
# 8926c803cd797330ee7c8e545b713874  HJdEI1q4SV-c5Di43BTT_Q
# b4e3df7fc6dd72505759959857a391fd  HJdEI1q4SV-c5Di43BTT_Q

# %%
df_f = pd.DataFrame(
    df.groupby(['sp.solvent_name', 'sp.solute_name']).first()['doc.SoluteInSolventAlchemicalFlow'].apply(lambda x: x['free_energy']['mean'] if 'free_energy' in x.keys() else None)
).reset_index()
df_f = df_f.pivot(index="sp.solute_name", columns="sp.solvent_name", values='doc.SoluteInSolventAlchemicalFlow')
df_f = df_f.apply(lambda x: x * 2.479) # kT to kJ/mol at 298K
df_f = df_f.iloc[:, :-1].sub(df_f["W"], axis=0).assign(W=df_f["W"])
df_f.rename(
    columns={
        "CHEX": "CHEX -> W", 
        "CLF": "CLF -> W", 
        "ETH": "ETH -> W", 
        "HD": "HD -> W", 
    }, 
    inplace=True
)
df_f = df_f[[
    "HD -> W", 
    "CLF -> W", 
    "ETH -> W", 
    "CHEX -> W", 
    "W",
]].reset_index()
df_f.columns.name = None
df_f = df_f.set_index("sp.solute_name")
df_f.index.name = "bead"
df_f.head()
# Out:
#       HD -> W  CLF -> W  ETH -> W  CHEX -> W      W
# bead
# P6     -27.98    -12.06    -11.05     -19.11  18.03

# %%
df_martini = pd.read_csv("martini_reg_ref.csv")
df_martini = df_martini.rename(
    columns={
        "Bead": "bead", 
        'Oil-water transfer ΔG (HD→W)': "HD -> W",
        'Oil-water transfer ΔG (OCO→W)': "OCO -> W",
        'Oil-water transfer ΔG (CLF→W)': "CLF -> W",
        'Oil-water transfer ΔG (ETH→W)': "ETH -> W",
        'Oil-water transfer ΔG (BENZ→W)': "BENZ -> W", 
        'Oil-water transfer ΔG (CHEX→W)': "CHEX -> W",
        'Hydration ΔG': "W"
    }
).drop(['Vaporization ΔG', "BENZ -> W", "OCO -> W"], axis=1).set_index("bead")
df_martini.head()
# Out:
#       HD -> W  CLF -> W  ETH -> W  CHEX -> W    W
# bead
# C1       17.2      17.2      14.5       20.0 -8.6
# C2       15.4      14.3      12.9       16.9 -5.7
# C3       13.5      13.3      13.3       16.3 -4.8
# C4       10.6      13.6      13.7       16.3 -5.1
# C5        8.8      12.1      11.9       13.2 -3.6

# %%
bead_mapping = {
    'N3a': 'N3d/a',
    'N3d': 'N3d/a',
    'Q2+': 'Q2',
}

def map_beads(bead):
    return bead_mapping.get(bead, bead)

df_f.index = [map_beads(bead) for bead in df_f.index]
df_f.index.name = "bead"

identical_beads = pd.merge(df_f, df_martini, on="bead").index
identical_beads
# Out:
# Index(['P6'], dtype='object', name='bead')

# %%
df_comp = df_f.loc[identical_beads].copy().compare(df_martini.loc[identical_beads].copy(), result_names=('Martignac', 'Souza et al.'))
df_comp
# Out:
#        HD -> W               CLF -> W               ETH -> W               \
#      Martignac Souza et al. Martignac Souza et al. Martignac Souza et al.
# bead
# P6      -27.98        -27.2    -12.06        -11.9    -11.05        -11.2
#
#      CHEX -> W                      W
#      Martignac Souza et al. Martignac Souza et al.
# bead
# P6      -19.11        -19.0     18.03         18.0

# %%
# Define the threshold for highlighting
thresholds = [1.0, 2.0, 3.0]
colors = ["yellow", "orange", "red"]

# Extract 'self' and 'other' values from the comparison DataFrame
df_self = df_comp.loc[:, (slice(None), 'Martignac')]
df_other = df_comp.loc[:, (slice(None), 'Souza et al.')]

# Function to apply highlighting to the 'self' values
def apply_highlighting(df_self, df_other):
    # Prepare a DataFrame to hold styles
    styles = pd.DataFrame('', index=df_self.index, columns=df_self.columns)

    def format_value(val):
        try:
            return '{:.2f}'.format(val)
        except (TypeError, ValueError):
            return val
    
    # Apply highlighting only to 'self' values
    for row in range(df_self.shape[0]):
        for col in range(df_self.shape[1]):
            val_self = df_self.iloc[row, col]
            val_other = df_other.iloc[row, col]

            for threshold, color in zip(thresholds, colors):
                if abs(val_self - val_other) > threshold:
                    styles.iloc[row, col] = f'background-color: {color}'

    
    return df_comp.style.format(format_value).apply(lambda x: styles, axis=None)

# Apply highlighting and display the styled DataFrame
styled_comp = apply_highlighting(df_self, df_other)
styled_comp
# Out:
# <style type="text/css">
# </style>
# <table id="T_a3bc6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3bc6_level0_col0" class="col_heading level0 col0" colspan="2">HD -> W</th>
#       <th id="T_a3bc6_level0_col2" class="col_heading level0 col2" colspan="2">CLF -> W</th>
#       <th id="T_a3bc6_level0_col4" class="col_heading level0 col4" colspan="2">ETH -> W</th>
#       <th id="T_a3bc6_level0_col6" class="col_heading level0 col6" colspan="2">CHEX -> W</th>
#       <th id="T_a3bc6_level0_col8" class="col_heading level0 col8" colspan="2">W</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a3bc6_level1_col0" class="col_heading level1 col0" >Martignac</th>
#       <th id="T_a3bc6_level1_col1" class="col_heading level1 col1" >Souza et al.</th>
#       <th id="T_a3bc6_level1_col2" class="col_heading level1 col2" >Martignac</th>
#       <th id="T_a3bc6_level1_col3" class="col_heading level1 col3" >Souza et al.</th>
#       <th id="T_a3bc6_level1_col4" class="col_heading level1 col4" >Martignac</th>
#       <th id="T_a3bc6_level1_col5" class="col_heading level1 col5" >Souza et al.</th>
#       <th id="T_a3bc6_level1_col6" class="col_heading level1 col6" >Martignac</th>
#       <th id="T_a3bc6_level1_col7" class="col_heading level1 col7" >Souza et al.</th>
#       <th id="T_a3bc6_level1_col8" class="col_heading level1 col8" >Martignac</th>
#       <th id="T_a3bc6_level1_col9" class="col_heading level1 col9" >Souza et al.</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bead</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3bc6_level0_row0" class="row_heading level0 row0" >P6</th>
#       <td id="T_a3bc6_row0_col0" class="data row0 col0" >-27.98</td>
#       <td id="T_a3bc6_row0_col1" class="data row0 col1" >-27.20</td>
#       <td id="T_a3bc6_row0_col2" class="data row0 col2" >-12.06</td>
#       <td id="T_a3bc6_row0_col3" class="data row0 col3" >-11.90</td>
#       <td id="T_a3bc6_row0_col4" class="data row0 col4" >-11.05</td>
#       <td id="T_a3bc6_row0_col5" class="data row0 col5" >-11.20</td>
#       <td id="T_a3bc6_row0_col6" class="data row0 col6" >-19.11</td>
#       <td id="T_a3bc6_row0_col7" class="data row0 col7" >-19.00</td>
#       <td id="T_a3bc6_row0_col8" class="data row0 col8" >18.03</td>
#       <td id="T_a3bc6_row0_col9" class="data row0 col9" >18.00</td>
#     </tr>
#   </tbody>
# </table>
