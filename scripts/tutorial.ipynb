# %% [markdown]
# # Martignac tutorial
#
# This Jupyter notebook is meant to introduce how Martignac is typically used, together with a number of functionalities. For this tutorial we'll focus on generating a solute (i.e., the simplest Martignac workflow).
#
# Before you go any further, please read the `README.md` and the online documentation to check that you have installed and configured everything. Also do go through the Martignac configuration file, the default configuration being stored in `martignac/config_default.yaml`. Configurations include notably the NOMAD parameters, as well as the paths for the local simulation input and output directories and files.
#
# Let's first import a number of functions we'll be using.

# %%
from dataclasses import asdict
from pprint import pprint

from martignac.nomad.users import search_users_by_name
from martignac.nomad.datasets import retrieve_datasets, create_dataset, delete_dataset
from martignac.nomad.entries import get_entry_by_id
from martignac.workflows.solute_generation import project as solute_gen_flow_project

# %% [markdown]
# ## NOMAD API connection
#
# Martignac is tightly integrated with NOMAD (<https://nomad-lab.eu/nomad-lab/>). NOMAD is a state-of-the-art webserver to normalize, store, and share materials-science data. It supports Gromacs, which is the molecular dynamics simulation engine we'll be using here.
#
# First, make sure you have a NOMAD account and that you've exported the environment variables `NOMAD_USERNAME` and `NOMAD_PASSWORD`.
#
# Because we're running tests, we'll systematically work with the `test` database---**not the production one**. Make sure this is correctly configured in your configuration `config.yaml` file, either located in the `martignac/martignac` directory, or perhaps more conveniently stored in your current directory. The yaml file should contain the following:
#
# ``` yaml
# nomad:
#   upload_to_nomad: true
#   publish_uploads: false
#   use_prod: false
# ```
# which indicates that we will be uploading simulations to NOMAD, we will **not** be publishing the entries (that's permanent!), and we will use the NOMAD test database (`use_prod: False`).
#
# Let's first look for a NOMAD user object. Feel free to replace the query name by yours, and try to find yourself:

# %%
users = search_users_by_name("Bereau", use_prod=False)
users
# Out:
# 24-08-23 14:42:45 - martignac.nomad.users - INFO - retrieving user Bereau on test server
# 24-08-23 14:42:45 - martignac.nomad.utils - INFO - Sending get request @ https://nomad-lab.eu/prod/v1/test/api/v1/users?prefix=Bereau
# [NomadUser(name='Tristan Bereau')]

# %% [markdown]
# The object contains various attributes:

# %%
user = users[0]
user.__dict__
# Out:
# {'user_id': '30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b',
#  'name': 'Tristan Bereau',
#  'first_name': 'Tristan',
#  'last_name': 'Bereau',
#  'username': 'tbereau',
#  'affiliation': 'Heidelberg University',
#  'affiliation_address': 'Heidelberg, Germany',
#  'email': None,
#  'is_oasis_admin': False,
#  'is_admin': False,
#  'repo_user_id': None,
#  'created': datetime.datetime(2023, 5, 23, 14, 22, 15, 547000, tzinfo=datetime.timezone(datetime.timedelta(0), '+0000'))}

# %% [markdown]
# Let's have a look at the datasets attached to the NOMAD user:

# %%
my_datasets = retrieve_datasets(user_id=user.user_id, use_prod=False)
pprint([asdict(d) for d in my_datasets])
# Out:
# 24-08-23 15:56:58 - martignac.nomad.utils - INFO - Sending get request @ https://nomad-lab.eu/prod/v1/test/api/v1/datasets/?user_id=30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b&page_size=10
# 24-08-23 15:56:58 - martignac.nomad.users - INFO - retrieving user 30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b on prod server
# 24-08-23 15:56:58 - martignac.nomad.utils - INFO - Sending get request @ https://nomad-lab.eu/prod/v1/test/api/v1/users/30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b
# [{'dataset_create_time': datetime.datetime(2024, 2, 14, 9, 39, 55, 876000),
#   'dataset_id': 'HJdEI1q4SV-c5Di43BTT_Q',
#   'dataset_modified_time': datetime.datetime(2024, 2, 14, 9, 39, 55, 876000),
#   'dataset_name': 'Martignac test dataset',
#   'dataset_type': 'DatasetType.owned',
#   'doi': None,
#   'm_annotations': None,
#   'pid': None,
#   'use_prod': False,
#   'user': {'affiliation': 'Heidelberg University',
#            'affiliation_address': 'Heidelberg, Germany',
#            'created': None,
#            'email': None,
#            'first_name': 'Tristan',
#            'is_admin': None,
#            'is_oasis_admin': None,
#            'last_name': 'Bereau',
#            'name': 'Tristan Bereau',
#            'repo_user_id': None,
#            'user_id': '30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b',
#            'username': 'tbereau'}},
#  {'dataset_create_time': datetime.datetime(2024, 8, 20, 11, 15, 40, 253000),
#   'dataset_id': 'IZYdt0ZhQeWq63WoyavGsQ',
#   'dataset_modified_time': datetime.datetime(2024, 8, 20, 11, 15, 40, 253000),
#   'dataset_name': 'Test dataset b4e9c0c3d20f95abe3f2aaf1bbb540a9',
#   'dataset_type': 'DatasetType.owned',
#   'doi': None,
#   'm_annotations': None,
#   'pid': None,
#   'use_prod': False,
#   'user': {'affiliation': 'Heidelberg University',
#            'affiliation_address': 'Heidelberg, Germany',
#            'created': None,
#            'email': None,
#            'first_name': 'Tristan',
#            'is_admin': None,
#            'is_oasis_admin': None,
#            'last_name': 'Bereau',
#            'name': 'Tristan Bereau',
#            'repo_user_id': None,
#            'user_id': '30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b',
#            'username': 'tbereau'}},
#  {'dataset_create_time': datetime.datetime(2024, 8, 23, 12, 43, 56, 24000),
#   'dataset_id': 'nla3SC_5TAKT5S08kKTXYQ',
#   'dataset_modified_time': datetime.datetime(2024, 8, 23, 12, 43, 56, 24000),
#   'dataset_name': 'Martignac tutorial',
#   'dataset_type': 'DatasetType.owned',
#   'doi': None,
#   'm_annotations': None,
#   'pid': None,
#   'use_prod': False,
#   'user': {'affiliation': 'Heidelberg University',
#            'affiliation_address': 'Heidelberg, Germany',
#            'created': None,
#            'email': None,
#            'first_name': 'Tristan',
#            'is_admin': None,
#            'is_oasis_admin': None,
#            'last_name': 'Bereau',
#            'name': 'Tristan Bereau',
#            'repo_user_id': None,
#            'user_id': '30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b',
#            'username': 'tbereau'}}]

# %% [markdown]
# I will now create a new dataset specifically for this tutorial

# %%
dataset_id = create_dataset("Martignac tutorial", use_prod=False)
dataset_id
# Out:
# 24-08-23 14:43:55 - martignac.nomad.datasets - INFO - creating dataset name Martignac tutorial on test server
# 24-08-23 14:43:55 - martignac.nomad.utils - INFO - Requesting authentication token @ https://nomad-lab.eu/prod/v1/test/api/v1
# 24-08-23 14:43:55 - martignac.nomad.utils - INFO - Sending post request @ https://nomad-lab.eu/prod/v1/test/api/v1/datasets/
# 'nla3SC_5TAKT5S08kKTXYQ'

# %% [markdown]
# You can access your datasets on the NOMAD GUI, simply head to <https://nomad-lab.eu/prod/v1/test/gui/user/datasets> (test database).
#
# If you set this ID in your Martignac config `config.yaml` file, any Martignac simulations will be pulled from and pushed to this dataset.
#
# Let's fetch a simulation entry from NOMAD. The entry has ID `IWfLp8VCyT7z9t3BtVy21Q5WZSRW`. The flag `with_authentication` is only necessary when we're querying private entries, for which a bearer token is required from the API. As you can see, the entry contains lots of information:

# %%
entry_id = "IWfLp8VCyT7z9t3BtVy21Q5WZSRW"
entry = get_entry_by_id(entry_id, with_authentication=False, use_prod=False)
pprint(asdict(entry))
# Out:
# {'authors': [{'affiliation': 'Heidelberg University',
#               'affiliation_address': 'Heidelberg, Germany',
#               'created': None,
#               'email': None,
#               'first_name': 'Tristan',
#               'is_admin': None,
#               'is_oasis_admin': None,
#               'last_name': 'Bereau',
#               'name': 'Tristan Bereau',
#               'repo_user_id': None,
#               'user_id': '30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b',
#               'username': 'tbereau'}],
#  'calc_id': 'IWfLp8VCyT7z9t3BtVy21Q5WZSRW',
#  'comment': None,
#  'datasets': [{'dataset_create_time': datetime.datetime(2024, 2, 14, 9, 39, 55, 876000, tzinfo=datetime.timezone(datetime.timedelta(0), '+0000')),
#                'dataset_id': 'HJdEI1q4SV-c5Di43BTT_Q',
#                'dataset_modified_time': datetime.datetime(2024, 2, 14, 9, 39, 55, 876000, tzinfo=datetime.timezone(datetime.timedelta(0), '+0000')),
#                'dataset_name': 'Martignac test dataset',
#                'dataset_type': 'DatasetType.owned',
#                'doi': None,
#                'm_annotations': {'mongo': ['MongoInstance']},
#                'pid': None,
#                'use_prod': None,
#                'user': None}],
#  'domain': 'dft',
#  'entry_create_time': datetime.datetime(2024, 2, 14, 9, 43, 59, 527000, tzinfo=datetime.timezone(datetime.timedelta(0), '+0000')),
#  'entry_id': 'IWfLp8VCyT7z9t3BtVy21Q5WZSRW',
#  'entry_name': 'GROMACS MolecularDynamics simulation',
#  'entry_references': None,
#  'entry_type': 'GROMACS MolecularDynamics',
#  'files': ['008bec4a5b5a9ef9dc344f7105eaf20f/fep_run-7.log',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/fep_run-7.cpt',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/fep_run-7.edr',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/fep_run-7.gro',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/fep_run-7.tpr',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/fep_run-7.xtc',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/fep_run-7.xvg',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/mdout.mdp',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/run_lambda.mdp',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/signac_job_document.json',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/signac_statepoint.json',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/solute.itp',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/solute_solvent.top',
#            '008bec4a5b5a9ef9dc344f7105eaf20f/solute_solvent_equ.gro'],
#  'last_processing_time': datetime.datetime(2024, 2, 14, 9, 43, 59, 911000, tzinfo=datetime.timezone(datetime.timedelta(0), '+0000')),
#  'license': 'CC BY 4.0',
#  'main_author': {'affiliation': 'Heidelberg University',
#                  'affiliation_address': 'Heidelberg, Germany',
#                  'created': None,
#                  'email': None,
#                  'first_name': 'Tristan',
#                  'is_admin': None,
#                  'is_oasis_admin': None,
#                  'last_name': 'Bereau',
#                  'name': 'Tristan Bereau',
#                  'repo_user_id': None,
#                  'user_id': '30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b',
#                  'username': 'tbereau'},
#  'mainfile': '008bec4a5b5a9ef9dc344f7105eaf20f/fep_run-7.log',
#  'n_quantities': 0,
#  'nomad_commit': '',
#  'nomad_version': '1.2.2.dev365+g0c980916a',
#  'optimade': None,
#  'origin': 'Tristan Bereau',
#  'parser_name': 'parsers/gromacs',
#  'processed': True,
#  'processing_errors': ['Error creating MDAnalysis universe.',
#                        'Error creating MDAnalysis universe.',
#                        'Error creating MDAnalysis universe.',
#                        'Error parsing interactions.',
#                        'Error creating MDAnalysis universe.',
#                        'Error creating MDAnalysis universe.',
#                        'Error creating MDAnalysis universe.',
#                        'Error creating MDAnalysis universe.',
#                        'Error creating MDAnalysis universe.',
#                        'Error creating MDAnalysis universe.',
#                        'Error creating MDAnalysis universe.'],
#  'publish_time': datetime.datetime(2024, 2, 14, 12, 23, 57, 957000, tzinfo=datetime.timezone(datetime.timedelta(0), '+0000')),
#  'published': True,
#  'quantities': ['',
#                 'metadata',
#                 'metadata.coauthor_groups',
#                 'metadata.coauthors',
#                 'metadata.datasets',
#                 'metadata.domain',
#                 'metadata.embargo_length',
#                 'metadata.entry_coauthors',
#                 'metadata.entry_create_time',
#                 'metadata.entry_hash',
#                 'metadata.entry_id',
#                 'metadata.entry_name',
#                 'metadata.entry_timestamp',
#                 'metadata.entry_timestamp.timestamp',
#                 'metadata.entry_timestamp.token',
#                 'metadata.entry_timestamp.token_seed',
#                 'metadata.entry_timestamp.tsa_server',
#                 'metadata.entry_type',
#                 'metadata.files',
#                 'metadata.last_processing_time',
#                 'metadata.license',
#                 'metadata.main_author',
#                 'metadata.mainfile',
#                 'metadata.nomad_commit',
#                 'metadata.nomad_version',
#                 'metadata.parser_name',
#                 'metadata.processed',
#                 'metadata.processing_errors',
#                 'metadata.published',
#                 'metadata.quantities',
#                 'metadata.references',
#                 'metadata.reviewer_groups',
#                 'metadata.reviewers',
#                 'metadata.section_defs',
#                 'metadata.section_defs.definition_id',
#                 'metadata.section_defs.definition_qualified_name',
#                 'metadata.section_defs.used_directly',
#                 'metadata.sections',
#                 'metadata.upload_create_time',
#                 'metadata.upload_id',
#                 'metadata.with_embargo',
#                 'results',
#                 'results.material',
#                 'results.method',
#                 'results.method.simulation',
#                 'results.method.simulation.precision',
#                 'results.method.simulation.program_name',
#                 'results.method.simulation.program_version',
#                 'results.method.workflow_name',
#                 'results.properties',
#                 'results.properties.n_calculations',
#                 'results.properties.thermodynamic',
#                 'results.properties.thermodynamic.trajectory',
#                 'results.properties.thermodynamic.trajectory.available_properties',
#                 'results.properties.thermodynamic.trajectory.energy_potential',
#                 'results.properties.thermodynamic.trajectory.energy_potential.time',
#                 'results.properties.thermodynamic.trajectory.energy_potential.value',
#                 'results.properties.thermodynamic.trajectory.pressure',
#                 'results.properties.thermodynamic.trajectory.pressure.time',
#                 'results.properties.thermodynamic.trajectory.pressure.value',
#                 'results.properties.thermodynamic.trajectory.provenance',
#                 'results.properties.thermodynamic.trajectory.provenance.molecular_dynamics',
#                 'results.properties.thermodynamic.trajectory.provenance.molecular_dynamics.ensemble_type',
#                 'results.properties.thermodynamic.trajectory.provenance.molecular_dynamics.time_step',
#                 'results.properties.thermodynamic.trajectory.temperature',
#                 'results.properties.thermodynamic.trajectory.temperature.time',
#                 'results.properties.thermodynamic.trajectory.temperature.value',
#                 'results.properties.thermodynamic.trajectory.volume',
#                 'results.properties.thermodynamic.trajectory.volume.time',
#                 'results.properties.thermodynamic.trajectory.volume.value',
#                 'run',
#                 'run.calculation',
#                 'run.calculation.density',
#                 'run.calculation.energy',
#                 'run.calculation.energy.electrostatic',
#                 'run.calculation.energy.electrostatic.short_range',
#                 'run.calculation.energy.electrostatic.value',
#                 'run.calculation.energy.kinetic',
#                 'run.calculation.energy.kinetic.value',
#                 'run.calculation.energy.potential',
#                 'run.calculation.energy.potential.value',
#                 'run.calculation.energy.pressure_volume_work',
#                 'run.calculation.energy.pressure_volume_work.value',
#                 'run.calculation.energy.total',
#                 'run.calculation.energy.total.value',
#                 'run.calculation.energy.van_der_waals',
#                 'run.calculation.energy.van_der_waals.short_range',
#                 'run.calculation.energy.van_der_waals.value',
#                 'run.calculation.energy.x_gromacs_energy_contributions',
#                 'run.calculation.energy.x_gromacs_energy_contributions.kind',
#                 'run.calculation.energy.x_gromacs_energy_contributions.value',
#                 'run.calculation.enthalpy',
#                 'run.calculation.method_ref',
#                 'run.calculation.pressure',
#                 'run.calculation.pressure_tensor',
#                 'run.calculation.step',
#                 'run.calculation.temperature',
#                 'run.calculation.time',
#                 'run.calculation.virial_tensor',
#                 'run.calculation.volume',
#                 'run.calculation.x_gromacs_thermodynamics_contributions',
#                 'run.calculation.x_gromacs_thermodynamics_contributions.kind',
#                 'run.calculation.x_gromacs_thermodynamics_contributions.value',
#                 'run.method',
#                 'run.method.force_field',
#                 'run.method.force_field.force_calculations',
#                 'run.method.force_field.force_calculations.coulomb_cutoff',
#                 'run.method.force_field.force_calculations.coulomb_type',
#                 'run.method.force_field.force_calculations.neighbor_searching',
#                 'run.method.force_field.force_calculations.neighbor_searching.neighbor_update_cutoff',
#                 'run.method.force_field.force_calculations.neighbor_searching.neighbor_update_frequency',
#                 'run.method.force_field.force_calculations.vdw_cutoff',
#                 'run.method.force_field.model',
#                 'run.method.force_field.model.contributions',
#                 'run.method.force_field.model.contributions.n_interactions',
#                 'run.method.force_field.model.contributions.parameters',
#                 'run.method.force_field.model.contributions.type',
#                 'run.program',
#                 'run.program.name',
#                 'run.program.version',
#                 'run.time_run',
#                 'run.time_run.date_end',
#                 'run.x_gromacs_section_control_parameters',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_acc',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_annealing',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_annealingnpoints',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_bdfric',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_c_compiler',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_c_compiler_flags',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_commmode',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_compressedxprecision',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_compressibility',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_constraintalgorithm',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_continuation',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_cosacceleration',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_coulombmodifier',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_coulombtype',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_cutoffscheme',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_deform',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_dispcorr',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_disre',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_disremixed',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_disreweighting',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_drfc',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_drtau',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_dt',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_emstep',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_emtol',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_epsilonr',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_epsilonrf',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_epsilonsurface',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_ewaldgeometry',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_ewaldrtol',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_ewaldrtollj',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_fcstep',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_fouriernx',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_fourierny',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_fouriernz',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_fourierspacing',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_freeenergy',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_gpu_support',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_initstep',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_integrator',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_interactivemd',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_ldseed',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_lincsiter',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_lincsorder',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_lincswarnangle',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_ljpmecombrule',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_memory_model',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_mpi_library',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nbfgscorr',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nfreeze',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_ngqm',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nhchainlength',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_niter',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nrdf',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstcalcenergy',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstcgsteep',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstcomm',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstdisreout',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstenergy',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nsteps',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstfout',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstlist',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstlog',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstorireout',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstpcouple',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nsttcouple',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstvout',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstxout',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nstxoutcompressed',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_nwall',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_openmp_support',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_orirefc',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_oriretau',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_pbc',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_pcoupl',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_pcoupltype',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_periodicmolecules',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_pmeorder',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_posrescom',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_posrescomb',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_precision',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_printnosehooverchainvariables',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_pull',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_qmmm',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_rcoulomb',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_rcoulombswitch',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_rdtscp_usage',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_refcoordscaling',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_refp',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_reft',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_rlist',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_rotation',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_rtpi',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_rvdw',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_rvdwswitch',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_shakesor',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_shaketol',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_simd_instructions',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_simulatedtempering',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_simulationpart',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_swapcoords',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_tableextension',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_taup',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_taut',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_tcoupl',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_tinit',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_tng_support',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_tracing_support',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_userint1',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_userint2',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_userint3',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_userint4',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_userreal1',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_userreal2',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_userreal3',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_userreal4',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_vdwmodifier',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_vdwtype',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_verletbuffertolerance',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_wallatomtype',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_walldensity',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_wallewaldzfac',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_wallrlinpot',
#                 'run.x_gromacs_section_control_parameters.x_gromacs_inout_control_walltype',
#                 'run.x_gromacs_section_input_output_files',
#                 'run.x_gromacs_section_input_output_files.x_gromacs_inout_file_eneredr',
#                 'run.x_gromacs_section_input_output_files.x_gromacs_inout_file_topoltpr',
#                 'run.x_gromacs_section_input_output_files.x_gromacs_inout_file_trajtrr',
#                 'workflow2',
#                 'workflow2.inputs',
#                 'workflow2.inputs.name',
#                 'workflow2.inputs.section',
#                 'workflow2.method',
#                 'workflow2.method.barostat_parameters',
#                 'workflow2.method.barostat_parameters.barostat_type',
#                 'workflow2.method.barostat_parameters.compressibility',
#                 'workflow2.method.barostat_parameters.coupling_constant',
#                 'workflow2.method.barostat_parameters.coupling_type',
#                 'workflow2.method.barostat_parameters.reference_pressure',
#                 'workflow2.method.integration_timestep',
#                 'workflow2.method.integrator_type',
#                 'workflow2.method.n_steps',
#                 'workflow2.method.thermodynamic_ensemble',
#                 'workflow2.method.thermodynamics_save_frequency',
#                 'workflow2.method.thermostat_parameters',
#                 'workflow2.method.thermostat_parameters.coupling_constant',
#                 'workflow2.method.thermostat_parameters.reference_temperature',
#                 'workflow2.method.thermostat_parameters.thermostat_type',
#                 'workflow2.outputs',
#                 'workflow2.outputs.name',
#                 'workflow2.outputs.section',
#                 'workflow2.results',
#                 'workflow2.results.calculation_result_ref',
#                 'workflow2.results.calculations_ref',
#                 'workflow2.results.temperature'],
#  'references': [],
#  'results': {'material': {'elements': [],
#                           'elements_exclusive': '',
#                           'n_elements': 0,
#                           'structural_type': 'not processed'},
#              'method': {'simulation': {'precision': {'basis_set': 'unavailable'},
#                                        'program_name': 'GROMACS',
#                                        'program_version': '2023.1-conda_forge',
#                                        'program_version_internal': 'not '
#                                                                    'processed'},
#                         'workflow_name': 'MolecularDynamics'},
#              'properties': {'available_properties': ['trajectory'],
#                             'n_calculations': 6,
#                             'thermodynamic': {'trajectory': [{'available_properties': ['volume',
#                                                                                        'pressure',
#                                                                                        'temperature',
#                                                                                        'energy_potential'],
#                                                               'provenance': {'molecular_dynamics': {'ensemble_type': 'NPT',
#                                                                                                     'time_step': 2e-14}}}]}}},
#  'section_defs': [{'definition_id': 'd9bbaf06854b47334aa61a8bc6ca6422cad6d881',
#                    'definition_qualified_name': 'atomisticparsers.gromacs.metainfo.gromacs.CalcEntry',
#                    'used_directly': True},
#                   {'definition_id': '096bd57cdf7bc2a4bdc7401091765321544aa959',
#                    'definition_qualified_name': 'atomisticparsers.gromacs.metainfo.gromacs.Calculation',
#                    'used_directly': True},
#                   {'definition_id': '9218fec4237d75780bc82b2026639f008ee8b8a1',
#                    'definition_qualified_name': 'atomisticparsers.gromacs.metainfo.gromacs.Energy',
#                    'used_directly': True},
#                   {'definition_id': '29cd9672a8d57bd2f301bdbc806d7589697340f6',
#                    'definition_qualified_name': 'atomisticparsers.gromacs.metainfo.gromacs.Interaction',
#                    'used_directly': True},
#                   {'definition_id': '1723a356edfbce4172eecdb485acad71a6305c20',
#                    'definition_qualified_name': 'atomisticparsers.gromacs.metainfo.gromacs.MolecularDynamics',
#                    'used_directly': True},
#                   {'definition_id': '8114357b1100947ba31fc70a13969069df2b9984',
#                    'definition_qualified_name': 'atomisticparsers.gromacs.metainfo.gromacs.Run',
#                    'used_directly': True},
#                   {'definition_id': '247f2d41ff42c7158d4be4bb6303815f1a17a583',
#                    'definition_qualified_name': 'atomisticparsers.gromacs.metainfo.gromacs.x_gromacs_section_control_parameters',
#                    'used_directly': True},
#                   {'definition_id': '91062ec6f4aa498e7e9c8407283565ff74e91052',
#                    'definition_qualified_name': 'atomisticparsers.gromacs.metainfo.gromacs.x_gromacs_section_input_output_files',
#                    'used_directly': True},
#                   {'definition_id': 'efcfa4a09151d1f1055b87cc372eef3588cc560e',
#                    'definition_qualified_name': 'electronicparsers.vasp.metainfo.vasp.Method',
#                    'used_directly': True},
#                   {'definition_id': '5313fb73e76a56d32ea23db23e6bb3e21bcbf96f',
#                    'definition_qualified_name': 'electronicparsers.vasp.metainfo.vasp.Run',
#                    'used_directly': True},
#                   {'definition_id': '4b967f2c84352177097aef742c5fb3bf96a69a50',
#                    'definition_qualified_name': 'electronicparsers.vasp.metainfo.vasp_incars.Method',
#                    'used_directly': True},
#                   {'definition_id': 'a035408027ad368715e62c3d4deea2271cca4e7d',
#                    'definition_qualified_name': 'electronicparsers.vasp.metainfo.vasp_incarsOut.Method',
#                    'used_directly': True},
#                   {'definition_id': '9001945827c2b4aed790ba55723c0afebd57d15b',
#                    'definition_qualified_name': 'electronicparsers.vasp.metainfo.vasp_incarsUnknown.Method',
#                    'used_directly': True},
#                   {'definition_id': '7047cbff9980abff17cce4b1b6b0d1c783505b7f',
#                    'definition_qualified_name': 'nomad.datamodel.data.ArchiveSection',
#                    'used_directly': True},
#                   {'definition_id': '538f52fd8d52b29372066f878319c6aeb03b74d2',
#                    'definition_qualified_name': 'nomad.datamodel.data.EntryData',
#                    'used_directly': False},
#                   {'definition_id': '0e24d45ceed55b563b3053dc1094e4a533c35e3e',
#                    'definition_qualified_name': 'nomad.datamodel.datamodel.EntryArchive',
#                    'used_directly': True},
#                   {'definition_id': '08e24de48352035bcc932ed9934875ed9b10188e',
#                    'definition_qualified_name': 'nomad.datamodel.datamodel.EntryMetadata',
#                    'used_directly': True},
#                   {'definition_id': '265ae33dbc9ace82b50260c1050d30c59ef9cb3c',
#                    'definition_qualified_name': 'nomad.datamodel.datamodel.RFC3161Timestamp',
#                    'used_directly': True},
#                   {'definition_id': '3238a80b7f1abc3c61277e33f049ff70c16002b5',
#                    'definition_qualified_name': 'nomad.datamodel.metainfo.common.PropertySection',
#                    'used_directly': False},
#                   {'definition_id': '410f8d4a48b11daaa2e01fc5d4946825155f272e',
#                    'definition_qualified_name': 'nomad.datamodel.metainfo.common.ProvenanceTracker',
#                    'used_directly': True},
#                   {'definition_id': '36539e90c9f93f81d9846055d8668bb23720bdf3',
#                    'definition_qualified_name': 'nomad.datamodel.metainfo.workflow.Link',
#                    'used_directly': True},
#                   {'definition_id': 'ac62fdff74f54fd477531446ca111c0dd9df6ba2',
#                    'definition_qualified_name': 'nomad.datamodel.metainfo.workflow.Task',
#                    'used_directly': False},
#                   {'definition_id': 'fc65ae24157492e422afe61173a71403fc5e1fd7',
#                    'definition_qualified_name': 'nomad.datamodel.metainfo.workflow.Workflow',
#                    'used_directly': False},
#                   {'definition_id': 'fcd1b5b54bb3ecbf55e734c4a374cd4abe44646c',
#                    'definition_qualified_name': 'nomad.datamodel.results.EnergyDynamic',
#                    'used_directly': True},
#                   {'definition_id': 'f336155b11cd68bda9276a12868ce230d16573a7',
#                    'definition_qualified_name': 'nomad.datamodel.results.MDPropertySection',
#                    'used_directly': True},
#                   {'definition_id': '7b686a3aca5b3d8a7a0a4b2e9d8b7db126a1315d',
#                    'definition_qualified_name': 'nomad.datamodel.results.MDProvenance',
#                    'used_directly': True},
#                   {'definition_id': 'f03e228478972e389a4e56c3b4dfe168d18145f4',
#                    'definition_qualified_name': 'nomad.datamodel.results.Material',
#                    'used_directly': True},
#                   {'definition_id': '224788210cd90b5012844ecabd1b0ee5242b4a76',
#                    'definition_qualified_name': 'nomad.datamodel.results.Method',
#                    'used_directly': True},
#                   {'definition_id': '2b2e9641df0f3f7d6c0b56c3b3866282af244bd3',
#                    'definition_qualified_name': 'nomad.datamodel.results.MolecularDynamics',
#                    'used_directly': True},
#                   {'definition_id': '56429cc9570d4e1de432f357105475484668e56f',
#                    'definition_qualified_name': 'nomad.datamodel.results.Precision',
#                    'used_directly': True},
#                   {'definition_id': 'af04e50859c372c874f0de396e565439c98806c8',
#                    'definition_qualified_name': 'nomad.datamodel.results.PressureDynamic',
#                    'used_directly': True},
#                   {'definition_id': 'b007ece5f0db074b42869babd0b8dd9865e80ed8',
#                    'definition_qualified_name': 'nomad.datamodel.results.Properties',
#                    'used_directly': True},
#                   {'definition_id': 'fbda04c1ac0c84a20b12588e160b68286d58512c',
#                    'definition_qualified_name': 'nomad.datamodel.results.QuantityDynamic',
#                    'used_directly': True},
#                   {'definition_id': 'cfc748229a8bb59a985b2a1021891dcf7852463c',
#                    'definition_qualified_name': 'nomad.datamodel.results.Results',
#                    'used_directly': True},
#                   {'definition_id': '2dcaa2565a4ad12a83403ca16de7a58bbce1dd1d',
#                    'definition_qualified_name': 'nomad.datamodel.results.Simulation',
#                    'used_directly': True},
#                   {'definition_id': '4786d30e0c1b9b9f37a8483175dc95342e803028',
#                    'definition_qualified_name': 'nomad.datamodel.results.TemperatureDynamic',
#                    'used_directly': True},
#                   {'definition_id': '4f7b4bccb508bd5318740fd68967e786c6eef6ff',
#                    'definition_qualified_name': 'nomad.datamodel.results.ThermodynamicProperties',
#                    'used_directly': True},
#                   {'definition_id': 'd3c0c0f086d49d9bbabe6e3dcac20dde8b76d051',
#                    'definition_qualified_name': 'nomad.datamodel.results.Trajectory',
#                    'used_directly': True},
#                   {'definition_id': '59585e11f7a85590e77759ab9a1c7145b647f916',
#                    'definition_qualified_name': 'nomad.datamodel.results.VolumeDynamic',
#                    'used_directly': True},
#                   {'definition_id': '7a39f29ea49cfc3bee0b552e044e1ab502d33449',
#                    'definition_qualified_name': 'runschema.calculation.Atomic',
#                    'used_directly': True},
#                   {'definition_id': '3ded328dfc4ee34b0c671e3e738062b02c470774',
#                    'definition_qualified_name': 'runschema.calculation.BaseCalculation',
#                    'used_directly': True},
#                   {'definition_id': '60fa84c655dd53b5a6f806d1c7fc0431a6373aaf',
#                    'definition_qualified_name': 'runschema.calculation.Calculation',
#                    'used_directly': True},
#                   {'definition_id': 'b33ac756f4d9fa620e93592a63989256c4624cb6',
#                    'definition_qualified_name': 'runschema.calculation.Energy',
#                    'used_directly': True},
#                   {'definition_id': '1a191a377ff1cb8ae1b4dbacf6d5734d30c3b74e',
#                    'definition_qualified_name': 'runschema.calculation.EnergyEntry',
#                    'used_directly': True},
#                   {'definition_id': '76a96bb8cebcbd0452953cdac99a8f398ec6c702',
#                    'definition_qualified_name': 'runschema.method.ForceCalculations',
#                    'used_directly': True},
#                   {'definition_id': 'f0a3b2b23cde5240c5164141ce35ba39f268db8c',
#                    'definition_qualified_name': 'runschema.method.ForceField',
#                    'used_directly': True},
#                   {'definition_id': '7083136a944a959f77466eb7961f9a7f44899cf8',
#                    'definition_qualified_name': 'runschema.method.Interaction',
#                    'used_directly': True},
#                   {'definition_id': 'd13673ee40f539ed32ee6c389ee893da325b1427',
#                    'definition_qualified_name': 'runschema.method.Method',
#                    'used_directly': True},
#                   {'definition_id': 'c1fb0c3588f59339c47f667fcb846236dedc6333',
#                    'definition_qualified_name': 'runschema.method.Model',
#                    'used_directly': True},
#                   {'definition_id': 'b5e3e4b442d566ca78c88e2995b1127b3b11908a',
#                    'definition_qualified_name': 'runschema.method.NeighborSearching',
#                    'used_directly': True},
#                   {'definition_id': 'f7e6f96f5243e129211a57832268dd05fa14d059',
#                    'definition_qualified_name': 'runschema.run.Program',
#                    'used_directly': True},
#                   {'definition_id': 'fc17fdfdcba5aef2c02835a81ed65f95f314b687',
#                    'definition_qualified_name': 'runschema.run.Run',
#                    'used_directly': True},
#                   {'definition_id': '59c33f305e7d6db3390a486100c3c1edb0ecab98',
#                    'definition_qualified_name': 'runschema.run.TimeRun',
#                    'used_directly': True},
#                   {'definition_id': '87fde45c10319cc65e04a9076e41cdc4611cfd9b',
#                    'definition_qualified_name': 'simulationworkflowschema.general.SerialSimulation',
#                    'used_directly': True},
#                   {'definition_id': '19df045699417abb29a73998cb61c42c562990e4',
#                    'definition_qualified_name': 'simulationworkflowschema.general.SimulationWorkflow',
#                    'used_directly': False},
#                   {'definition_id': '731e65a62ebdfbdef8ca7f4626525536b4f49f16',
#                    'definition_qualified_name': 'simulationworkflowschema.general.SimulationWorkflowMethod',
#                    'used_directly': True},
#                   {'definition_id': '62b07e02ddd1eb435409056f16094d2e12991f75',
#                    'definition_qualified_name': 'simulationworkflowschema.general.SimulationWorkflowResults',
#                    'used_directly': False},
#                   {'definition_id': 'e39d952ed2db72a413b588b493c3355239102005',
#                    'definition_qualified_name': 'simulationworkflowschema.molecular_dynamics.BarostatParameters',
#                    'used_directly': True},
#                   {'definition_id': '0340b1b6eacc138713e6536b0e163bfb2a7791d3',
#                    'definition_qualified_name': 'simulationworkflowschema.molecular_dynamics.MolecularDynamics',
#                    'used_directly': True},
#                   {'definition_id': 'fbcb2cea1081df954fd9ef461195305486131450',
#                    'definition_qualified_name': 'simulationworkflowschema.molecular_dynamics.MolecularDynamicsMethod',
#                    'used_directly': True},
#                   {'definition_id': 'bd51931a62361174dd2ef2189adf12c885a294e6',
#                    'definition_qualified_name': 'simulationworkflowschema.molecular_dynamics.MolecularDynamicsResults',
#                    'used_directly': True},
#                   {'definition_id': 'f48c182248f99acc02362a4fc1ad0fc2af2161bb',
#                    'definition_qualified_name': 'simulationworkflowschema.molecular_dynamics.ThermostatParameters',
#                    'used_directly': True},
#                   {'definition_id': '2a380eb042e3150c9910129a898d0a2cdccf737b',
#                    'definition_qualified_name': 'simulationworkflowschema.thermodynamics.ThermodynamicsResults',
#                    'used_directly': True}],
#  'sections': ['atomisticparsers.gromacs.metainfo.gromacs.CalcEntry',
#               'atomisticparsers.gromacs.metainfo.gromacs.x_gromacs_section_control_parameters',
#               'atomisticparsers.gromacs.metainfo.gromacs.x_gromacs_section_input_output_files',
#               'nomad.datamodel.datamodel.EntryArchive',
#               'nomad.datamodel.datamodel.EntryMetadata',
#               'nomad.datamodel.datamodel.RFC3161Timestamp',
#               'nomad.datamodel.metainfo.workflow.Link',
#               'nomad.datamodel.results.EnergyDynamic',
#               'nomad.datamodel.results.MDProvenance',
#               'nomad.datamodel.results.Material',
#               'nomad.datamodel.results.Method',
#               'nomad.datamodel.results.MolecularDynamics',
#               'nomad.datamodel.results.Precision',
#               'nomad.datamodel.results.PressureDynamic',
#               'nomad.datamodel.results.Properties',
#               'nomad.datamodel.results.Results',
#               'nomad.datamodel.results.Simulation',
#               'nomad.datamodel.results.TemperatureDynamic',
#               'nomad.datamodel.results.ThermodynamicProperties',
#               'nomad.datamodel.results.Trajectory',
#               'nomad.datamodel.results.VolumeDynamic',
#               'runschema.calculation.Calculation',
#               'runschema.calculation.Energy',
#               'runschema.calculation.EnergyEntry',
#               'runschema.method.ForceCalculations',
#               'runschema.method.ForceField',
#               'runschema.method.Interaction',
#               'runschema.method.Method',
#               'runschema.method.Model',
#               'runschema.method.NeighborSearching',
#               'runschema.run.Program',
#               'runschema.run.Run',
#               'runschema.run.TimeRun',
#               'simulationworkflowschema.molecular_dynamics.BarostatParameters',
#               'simulationworkflowschema.molecular_dynamics.MolecularDynamics',
#               'simulationworkflowschema.molecular_dynamics.MolecularDynamicsMethod',
#               'simulationworkflowschema.molecular_dynamics.MolecularDynamicsResults',
#               'simulationworkflowschema.molecular_dynamics.ThermostatParameters'],
#  'text_search_contents': [],
#  'upload_create_time': datetime.datetime(2024, 2, 14, 9, 43, 58, 640000, tzinfo=datetime.timezone(datetime.timedelta(0), '+0000')),
#  'upload_id': 'Hbwh9S0-RLehQIh90nfhAQ',
#  'upload_name': None,
#  'use_prod': False,
#  'viewer_groups': [],
#  'viewers': [{'affiliation': 'Heidelberg University',
#               'affiliation_address': 'Heidelberg, Germany',
#               'created': None,
#               'email': None,
#               'first_name': 'Tristan',
#               'is_admin': None,
#               'is_oasis_admin': None,
#               'last_name': 'Bereau',
#               'name': 'Tristan Bereau',
#               'repo_user_id': None,
#               'user_id': '30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b',
#               'username': 'tbereau'}],
#  'with_embargo': False,
#  'writer_groups': [],
#  'writers': [{'affiliation': 'Heidelberg University',
#               'affiliation_address': 'Heidelberg, Germany',
#               'created': None,
#               'email': None,
#               'first_name': 'Tristan',
#               'is_admin': None,
#               'is_oasis_admin': None,
#               'last_name': 'Bereau',
#               'name': 'Tristan Bereau',
#               'repo_user_id': None,
#               'user_id': '30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b',
#               'username': 'tbereau'}]}

# %% [markdown]
# ## MD simulation workflow
#
# Now let's run a simulation workflow. We'll focus on generating a solute. The Martignac workflow class is called `SoluteGenFlow`. Simply calling the project returns all the jobs that exist locally. If you start fresh, you'll likely have an empty dataframe

# %%
solute_gen_flow_project
# Out:
# SoluteGenFlow('/Users/bereau/work/projects/martignac/workspaces/solute_generation')

# %% [markdown]
# We've decided to generate the solute composed of a single bead type, "P6" in Martini. Following the `signac` design principle, each workflow is defined by its state point, which here corresponds to the chemistry used. In `signac`, a state point is a dictionary, which fully specifies the workflow. Let's define a new state point and add it (if it doesn't already exist) to the project. We'll "open the job", which means it either creates it or accesses it:

# %%
sp = {"type": "solute", "solute_name": "P6"}
job = solute_gen_flow_project.open_job(sp).init()
job
# Out:
# Job(project=SoluteGenFlow('/Users/bereau/work/projects/martignac/workspaces/solute_generation'), statepoint={'type': 'solute', 'solute_name': 'P6'})

# %% [markdown]
# Now we can run the job. Running will mean one of three things:
#
# 1. The job is present locally and has already been completed. Nothing needs to be done.
# 2. The job is either absent locally or has only partially been run. An attempt will be made at downloading from NOMAD the job. If the job is not on NOMAD, the job is continued locally.
# 3. The job is (partially) absent locally, but the job is present in NOMAD. The job is simply downloaded. The workflow is complete.
#
# To run the workflow, we simply need to invoke `solute_gen_flow_project.run()`. We can also restrict ourselves to the afore mentioned job:

# %%
solute_gen_flow_project.run(jobs=[job])
# Out:
# 24-08-23 16:06:56 - martignac.nomad.entries - INFO - retrieving entries for upload q-HvqWzAR8WIfkdai1z2Nw on test server
# 24-08-23 16:06:56 - martignac.nomad.utils - INFO - Sending get request @ https://nomad-lab.eu/prod/v1/test/api/v1/uploads/q-HvqWzAR8WIfkdai1z2Nw/entries
# 24-08-23 16:06:56 - martignac.nomad.users - INFO - retrieving user 30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b on prod server
# 24-08-23 16:06:56 - martignac.nomad.utils - INFO - Sending get request @ https://nomad-lab.eu/prod/v1/test/api/v1/users/30d3a108-d2cc-45ec-9ddb-0c1dc6a2c99b
# 24-08-23 16:06:56 - martignac.nomad.users - INFO - retrieving user 7c85bdf1-8b53-40a8-81a4-04f26ff56f29 on prod server
# 24-08-23 16:06:56 - martignac.nomad.utils - INFO - Sending get request @ https://nomad-lab.eu/prod/v1/test/api/v1/users/7c85bdf1-8b53-40a8-81a4-04f26ff56f29

# %% [markdown]
# As can be seen from the output, very little happened. In fact, the job already existed locally. Martignac simply sent a few requests to the NOMAD API to check that the NOMAD `entry_id` that's stored in the job in fact corresponds to what's online. The job stores metadata about the simulation workflow. This can be accessed in two commands. First, `job.sp` returns the `signac` state point:

# %%
job.sp
# Out:
# {'type': 'solute', 'solute_name': 'P6'}

# %% [markdown]
# The richer `job.doc` contains information that is Martignac specific:

# %%
pprint(dict(job.doc))
# Out:
# {'SoluteGenFlow': {'files_symlinked': True, 'fetched_nomad': True, 'gromacs_logs': {'minimize': 'solute_minimize.log', 'equilibrate': 'solute_equilibrate.log'}, 'itp_files': 'a52590b1d87d122ba1e376b83c3d6bee', 'mdp_files': '2d7a9e52d14d23e0dfb97192d75a3463', 'nomad_upload_id': 'q-HvqWzAR8WIfkdai1z2Nw', 'nomad_workflow': 'solute_generation.archive.yaml', 'ready_for_nomad_upload': True, 'tasks': {'build': 'run'}, 'solute_itp': 'solute.itp', 'solute_top': 'solute.top', 'solute_name': 'P6', 'solute_has_charged_beads': False, 'solute_gro': 'solute_equilibrate.gro'},
#  'nomad_dataset_id': 'HJdEI1q4SV-c5Di43BTT_Q'}

# %% [markdown]
# where the NOMAD dataset is stored in `nomad_dataset_id`. The information specific to the solute-generation workflow is stored in the key `SoluteGenFlow`. Several subkeys are specified, and are largely used as flags to check for the internal advancement of the workflow:
#
# - `files_symlinked`: itp and mdp files have already been symlinked
# - `fetched_nomad`: workflow fetching from NOMAD was attempted
# - `gromacs_logs`: node operations of the workflows consisting of MD simulations
# - `itp_files`: hash of the ITP files
# - `mdp_files`: hash of the MDP files
# - `nomad_upload_id`: NOMAD upload ID after workflow upload
# - `nomad_workflow`: name of the NOMAD workflow yaml file
# - `ready_for_nomad_upload`: flag to push to NOMAD
# - `tasks`: node operations of the workflows that are not MD simulations
# - `solute_itp`: ITP file of the solute
# - `solute_top`: TOP file of the solute
# - `solute_name`: name of the solute (i.e., identical to `job.sp["solute_name"]`)
# - `solute_has_charged_beads`: whether any bead is charged (for free-energy calculations)
# - `solute_gro`: GRO file of the solute
#
# The `job.doc` is significantly longer for more complex workflows, because it composes all workflows used. For instance, a solute-in-solvent generation will need the solute and solvent generation workflows, in addition to the SoluteInSolventGenFlow itself.

# %% [markdown]
# ## Remove your dataset
#
# You may want to clean things up and remove your simulations and dataset. You can remove simulations as long as you have not published them! However, NOMAD only allows you to have at most 10 unpublished uploads. From the NOMAD GUI you can access uploads: <https://nomad-lab.eu/prod/v1/test/gui/user/uploads>. From there, you can select the simulations you'd like to remove and click on the trash bin at the top right. Once you have remove all simulations from the dataset, you can also remove the dataset. This can be done through the API with the following command. If things run smoothly, you should get an acknowledgment in the logs ("successfully deleted dataset ..."):

# %%
delete_dataset(dataset_id, use_prod=False)
# Out:
# 24-08-23 16:20:27 - martignac.nomad.datasets - INFO - deleting dataset nla3SC_5TAKT5S08kKTXYQ on test server
# 24-08-23 16:20:27 - martignac.nomad.utils - INFO - Requesting authentication token @ https://nomad-lab.eu/prod/v1/test/api/v1
# 24-08-23 16:20:27 - martignac.nomad.utils - INFO - Sending delete request @ https://nomad-lab.eu/prod/v1/test/api/v1/datasets/nla3SC_5TAKT5S08kKTXYQ
# 24-08-23 16:20:27 - martignac.nomad.datasets - INFO - successfully deleted dataset nla3SC_5TAKT5S08kKTXYQ

# %% [markdown]
# ## That's all
#
# That's it for this tutorial. Head out to the paper and the online docs to have a closer look at the different simulation workflows. The docs also describe how to construct the initialization of jobs. Last, head out to the Martignac Streamlit app to browse existing simulations: <https://martignac.streamlit.app/>.
